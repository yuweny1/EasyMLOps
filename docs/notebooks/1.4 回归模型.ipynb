# %%
import os
os.chdir("../../")#与easymlops同级目录

# %% [markdown]
# ### 拆分数据

# %%
import pandas as pd
data=pd.read_csv("./data/demo.csv")
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
x_train=data[:500]
x_test=data[500:]
y_train=x_train["Survived"]
y_test=x_test["Survived"]
del x_train["Survived"]
del x_test["Survived"]

# %% [markdown]
# ### pipe构建

# %%
from easymlops import TablePipeLine
from easymlops.table.preprocessing import *
from easymlops.table.encoding import *
from easymlops.table.regression import *

# %%
table=TablePipeLine()
table.pipe(FixInput())\
  .pipe(FillNa())\
  .pipe(OneHotEncoding(cols=["Pclass", "Sex"], drop_col=False)) \
  .pipe(WOEEncoding(cols=["Ticket", "Embarked", "Cabin", "Sex", "Pclass"], y=y_train)) \
  .pipe(LabelEncoding(cols=["Name"]))\
  .pipe(LGBMRegression(y=y_train,objective="poisson"))

x_test_new=table.fit(x_train).transform(x_test)
x_test_new.head(5)
# Out:
#          pred
# 500  0.092996
# 501  0.716432
# 502  0.654662
# 503  0.309583
# 504  0.916929

# %%
#获取sabass特征重要性
table[-1].get_contrib(table.transform_single(x_test.to_dict("record")[0],run_to_layer=-2))
# Out:
# {'Sex': -0.5899834278029109,
#  'Cabin': -0.13150175316983173,
#  'Fare': -0.1301026457360956,
#  'Age': 0.275645992578784,
#  'PassengerId': -0.39285142163510006,
#  'Pclass_2': 0.0868239954973954,
#  'SibSp': 0.048242598427820915,
#  'Parch': -0.01823350433998343,
#  'Pclass': -0.01402473665988247,
#  'Ticket': -0.0030424253099006976,
#  'Embarked': -0.005601108385329127}

# %% [markdown]
# ### 性能、一致性测试

# %%
table.auto_test(x_test[:10])
# Out:
# ###################################################################
#  1.一致性测试和性能测试:check_transform_function
# ###################################################################
# (<class 'easymlops.table.preprocessing.core.FixInput'>) module check [transform] complete,speed:[0.3ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.FillNa'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.OneHotEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.WOEEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.LabelEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.regression.LGBMRegression'>) module check [transform] complete,speed:[6.33ms]/it,cpu:[83%],memory:[0K]
#
# #########################################################################################
#  2.空值测试:check_null_value
#  null_values=[None, np.nan, "null", "NULL", "nan", "NaN", "", "none", "None", " "](默认)
# ########################################################################################
# column:[PassengerId] check [null value] complete,speed:[2.3ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [null value] complete,speed:[2.47ms]/it,cpu:[100%],memory:[0K]
# column:[Name] check [null value] complete,speed:[2.13ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [null value] complete,speed:[1.56ms]/it,cpu:[0%],memory:[0K]
# column:[Age] check [null value] complete,speed:[1.5ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [null value] complete,speed:[2.45ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [null value] complete,speed:[2.26ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [null value] complete,speed:[2.15ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [null value] complete,speed:[1.83ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [null value] complete,speed:[2.49ms]/it,cpu:[100%],memory:[0K]
# column:[Embarked] check [null value] complete,speed:[2.29ms]/it,cpu:[0%],memory:[0K]
#
# ############################################################################################################
#  3.极端值测试:check_extreme_value
#  number_extreme_values = [np.inf, 0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  category_extreme_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1", "NaN", "None"](默认)
# ###########################################################################################################
# column:[PassengerId] check [extreme value] complete,speed:[2.99ms]/it,cpu:[100%],memory:[8232232K]
# column:[Pclass] check [extreme value] complete,speed:[2.44ms]/it,cpu:[100%],memory:[8231040K]
# column:[Name] check [extreme value] complete,speed:[1.55ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [extreme value] complete,speed:[2.63ms]/it,cpu:[100%],memory:[8231072K]
# column:[Age] check [extreme value] complete,speed:[2.4ms]/it,cpu:[100%],memory:[8253080K]
# column:[SibSp] check [extreme value] complete,speed:[1.96ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [extreme value] complete,speed:[2.35ms]/it,cpu:[100%],memory:[8254244K]
# column:[Ticket] check [extreme value] complete,speed:[2.03ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [extreme value] complete,speed:[2.34ms]/it,cpu:[100%],memory:[8250140K]
# column:[Cabin] check [extreme value] complete,speed:[2.26ms]/it,cpu:[100%],memory:[8250104K]
# column:[Embarked] check [extreme value] complete,speed:[2.5ms]/it,cpu:[0%],memory:[0K]
# column:[__all__] check [extreme value] complete,speed:[1.37ms]/it,cpu:[0%],memory:[0K]
#
# ###############################################################################################################
#  4.数据类型反转测试:check_inverse_dtype
#  category_inverse_values = [0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  number_inverse_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1"](默认)
# #############################################################################################################
# column:[PassengerId] check [inverse type] complete,speed:[2.28ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [inverse type] complete,speed:[2.46ms]/it,cpu:[0%],memory:[0K]
# column:[Name] check [inverse type] complete,speed:[2.12ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [inverse type] complete,speed:[2.01ms]/it,cpu:[100%],memory:[8241012K]
# column:[Age] check [inverse type] complete,speed:[1.66ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [inverse type] complete,speed:[2.28ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [inverse type] complete,speed:[2.01ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [inverse type] complete,speed:[2.16ms]/it,cpu:[100%],memory:[8240896K]
# column:[Fare] check [inverse type] complete,speed:[2.11ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [inverse type] complete,speed:[2.16ms]/it,cpu:[100%],memory:[8240668K]
# column:[Embarked] check [inverse type] complete,speed:[2.27ms]/it,cpu:[0%],memory:[0K]
#
# ############################################
#  5.int数据转float测试:check_int_trans_float
# ############################################
# column:[PassengerId] check [int trans float] complete,speed:[3.14ms]/it,cpu:[100%],memory:[0K]
# column:[Pclass] check [int trans float] complete,speed:[1.56ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [int trans float] complete,speed:[3.13ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [int trans float] complete,speed:[1.56ms]/it,cpu:[0%],memory:[0K]

# %% [markdown]
# ### 持久化测试

# %%
table.save("ml.pkl")

# %%
table=TablePipeLine()
table.pipe(FixInput())\
  .pipe(FillNa())\
  .pipe(OneHotEncoding(cols=["Pclass", "Sex"], drop_col=False)) \
  .pipe(WOEEncoding(cols=["Ticket", "Embarked", "Cabin", "Sex", "Pclass"])) \
  .pipe(LabelEncoding(cols=["Name"]))\
  .pipe(LGBMRegression(objective="poisson"))

table.load("ml.pkl")

# %%
table.auto_test(x_test[:10])
# Out:
# ###################################################################
#  1.一致性测试和性能测试:check_transform_function
# ###################################################################
# (<class 'easymlops.table.preprocessing.core.FixInput'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.FillNa'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.OneHotEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.WOEEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.LabelEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.regression.LGBMRegression'>) module check [transform] complete,speed:[1.56ms]/it,cpu:[0%],memory:[0K]
#
# #########################################################################################
#  2.空值测试:check_null_value
#  null_values=[None, np.nan, "null", "NULL", "nan", "NaN", "", "none", "None", " "](默认)
# ########################################################################################
# column:[PassengerId] check [null value] complete,speed:[2.5ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [null value] complete,speed:[1.75ms]/it,cpu:[100%],memory:[0K]
# column:[Name] check [null value] complete,speed:[2.09ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [null value] complete,speed:[1.88ms]/it,cpu:[0%],memory:[0K]
# column:[Age] check [null value] complete,speed:[2.31ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [null value] complete,speed:[2.3ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [null value] complete,speed:[1.99ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [null value] complete,speed:[2.56ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [null value] complete,speed:[2.13ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [null value] complete,speed:[2.71ms]/it,cpu:[0%],memory:[0K]
# column:[Embarked] check [null value] complete,speed:[2.04ms]/it,cpu:[0%],memory:[0K]
#
# ############################################################################################################
#  3.极端值测试:check_extreme_value
#  number_extreme_values = [np.inf, 0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  category_extreme_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1", "NaN", "None"](默认)
# ###########################################################################################################
# column:[PassengerId] check [extreme value] complete,speed:[2.67ms]/it,cpu:[100%],memory:[8239184K]
# column:[Pclass] check [extreme value] complete,speed:[1.72ms]/it,cpu:[0%],memory:[0K]
# column:[Name] check [extreme value] complete,speed:[2.2ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [extreme value] complete,speed:[1.96ms]/it,cpu:[0%],memory:[0K]
# column:[Age] check [extreme value] complete,speed:[2.04ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [extreme value] complete,speed:[2.19ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [extreme value] complete,speed:[1.73ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [extreme value] complete,speed:[1.99ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [extreme value] complete,speed:[1.8ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [extreme value] complete,speed:[2.19ms]/it,cpu:[0%],memory:[0K]
# column:[Embarked] check [extreme value] complete,speed:[2.24ms]/it,cpu:[100%],memory:[8224620K]
# column:[__all__] check [extreme value] complete,speed:[1.33ms]/it,cpu:[0%],memory:[0K]
#
# ###############################################################################################################
#  4.数据类型反转测试:check_inverse_dtype
#  category_inverse_values = [0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  number_inverse_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1"](默认)
# #############################################################################################################
# column:[PassengerId] check [inverse type] complete,speed:[2.48ms]/it,cpu:[100%],memory:[8223548K]
# column:[Pclass] check [inverse type] complete,speed:[2.01ms]/it,cpu:[0%],memory:[0K]
# column:[Name] check [inverse type] complete,speed:[2.27ms]/it,cpu:[100%],memory:[8222464K]
# column:[Sex] check [inverse type] complete,speed:[1.91ms]/it,cpu:[0%],memory:[0K]
# column:[Age] check [inverse type] complete,speed:[2.79ms]/it,cpu:[100%],memory:[8219760K]
# column:[SibSp] check [inverse type] complete,speed:[2.17ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [inverse type] complete,speed:[2.01ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [inverse type] complete,speed:[2.26ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [inverse type] complete,speed:[2.23ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [inverse type] complete,speed:[1.91ms]/it,cpu:[0%],memory:[0K]
# column:[Embarked] check [inverse type] complete,speed:[2.08ms]/it,cpu:[0%],memory:[0K]
#
# ############################################
#  5.int数据转float测试:check_int_trans_float
# ############################################
# column:[PassengerId] check [int trans float] complete,speed:[1.56ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [int trans float] complete,speed:[1.56ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [int trans float] complete,speed:[1.56ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [int trans float] complete,speed:[3.13ms]/it,cpu:[0%],memory:[0K]

# %%
table.transform(x_test[:5])
# Out:
#          pred
# 500  0.092996
# 501  0.716432
# 502  0.654662
# 503  0.309583
# 504  0.916929

# %%
x_test_new.head(5)
# Out:
#          pred
# 500  0.092996
# 501  0.716432
# 502  0.654662
# 503  0.309583
# 504  0.916929

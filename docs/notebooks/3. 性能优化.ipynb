# %%
import os
os.chdir("../../")#与easymlops同级目录

# %% [markdown]
# ### 拆分数据

# %%
import pandas as pd
data=pd.read_csv("./data/demo.csv")
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
x_train=data[:-500]
x_test=data[-500:]
y_train=x_train["Survived"]
y_test=x_test["Survived"]
del x_train["Survived"]
del x_test["Survived"]

# %% [markdown]
# ### pipe构建

# %%
from easymlops import TablePipeLine
from easymlops.table.preprocessing import *
from easymlops.table.encoding import *
from easymlops.table.perfopt import *

# %%
table=TablePipeLine()
table.pipe(FixInput())\
  .pipe(FillNa())\
  .pipe(Clip(cols=["Age"],default_clip=(1,99),name="clip_name"))\
  .pipe(OneHotEncoding(cols=["Pclass","Sex","Name","Ticket","Embarked","Cabin"],drop_col=True))\
  .pipe(ReduceMemUsage())\
  .pipe(Dense2Sparse())

x_train_new=table.fit(x_train).transform(x_train)
x_train_new.shape
# Out:
# (391, 814)

# %%
#原始
table.transform(x_train,run_to_layer=-3).memory_usage().sum()//1024
# Out:
# 312

# %%
#做了ReduceMemUsage后
table.transform(x_train,run_to_layer=-2).memory_usage().sum()//1024
# Out:
# 312

# %%
#做了ReduceMemUsage和Dense2Sparse后
table.transform(x_train,run_to_layer=-1).memory_usage().sum()//1024
# Out:
# 19

# %% [markdown]
# ### 性能、一致性测试

# %%
table.auto_test(x_test[:10])
# Out:
# ###################################################################
#  1.一致性测试和性能测试:check_transform_function
# ###################################################################
# (<class 'easymlops.table.preprocessing.core.FixInput'>) module check [transform] complete,speed:[1.69ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.FillNa'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (clip_name) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.OneHotEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.perfopt.ReduceMemUsage'>) module check [transform] complete,speed:[9.38ms]/it,cpu:[17%],memory:[0K]
# (<class 'easymlops.table.perfopt.Dense2Sparse'>) module check [transform] complete,speed:[10.94ms]/it,cpu:[19%],memory:[0K]
#
# #########################################################################################
#  2.空值测试:check_null_value
#  null_values=[None, np.nan, "null", "NULL", "nan", "NaN", "", "none", "None", " "](默认)
# ########################################################################################
# column:[PassengerId] check [null value] complete,speed:[21.95ms]/it,cpu:[20%],memory:[8144K]
# column:[Pclass] check [null value] complete,speed:[22.25ms]/it,cpu:[30%],memory:[128K]
# column:[Name] check [null value] complete,speed:[21.11ms]/it,cpu:[28%],memory:[0K]
# column:[Sex] check [null value] complete,speed:[21.75ms]/it,cpu:[45%],memory:[24K]
# column:[Age] check [null value] complete,speed:[20.91ms]/it,cpu:[16%],memory:[4K]
# column:[SibSp] check [null value] complete,speed:[21.66ms]/it,cpu:[28%],memory:[2192K]
# column:[Parch] check [null value] complete,speed:[21.87ms]/it,cpu:[48%],memory:[2156K]
# column:[Ticket] check [null value] complete,speed:[21.39ms]/it,cpu:[17%],memory:[4K]
# column:[Fare] check [null value] complete,speed:[21.32ms]/it,cpu:[25%],memory:[12K]
# column:[Cabin] check [null value] complete,speed:[21.49ms]/it,cpu:[16%],memory:[20K]
# column:[Embarked] check [null value] complete,speed:[22.08ms]/it,cpu:[42%],memory:[27196K]
#
# ############################################################################################################
#  3.极端值测试:check_extreme_value
#  number_extreme_values = [np.inf, 0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  category_extreme_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1", "NaN", "None"](默认)
# ###########################################################################################################
# column:[PassengerId] check [extreme value] complete,speed:[21.25ms]/it,cpu:[43%],memory:[21500K]
# column:[Pclass] check [extreme value] complete,speed:[22.03ms]/it,cpu:[34%],memory:[10652K]
# column:[Name] check [extreme value] complete,speed:[24.97ms]/it,cpu:[81%],memory:[23240K]
# column:[Sex] check [extreme value] complete,speed:[21.74ms]/it,cpu:[48%],memory:[17296K]
# column:[Age] check [extreme value] complete,speed:[21.12ms]/it,cpu:[44%],memory:[12768K]
# column:[SibSp] check [extreme value] complete,speed:[21.55ms]/it,cpu:[40%],memory:[224688K]
# column:[Parch] check [extreme value] complete,speed:[21.66ms]/it,cpu:[88%],memory:[248380K]
# column:[Ticket] check [extreme value] complete,speed:[20.99ms]/it,cpu:[26%],memory:[13152K]
# column:[Fare] check [extreme value] complete,speed:[21.78ms]/it,cpu:[67%],memory:[168600K]
# column:[Cabin] check [extreme value] complete,speed:[22.89ms]/it,cpu:[45%],memory:[21548K]
# column:[Embarked] check [extreme value] complete,speed:[21.03ms]/it,cpu:[43%],memory:[41508K]
# column:[__all__] check [extreme value] complete,speed:[21.41ms]/it,cpu:[87%],memory:[60256K]
#
# ###############################################################################################################
#  4.数据类型反转测试:check_inverse_dtype
#  category_inverse_values = [0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  number_inverse_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1"](默认)
# #############################################################################################################
# column:[PassengerId] check [inverse type] complete,speed:[21.16ms]/it,cpu:[78%],memory:[12804K]
# column:[Pclass] check [inverse type] complete,speed:[22.17ms]/it,cpu:[65%],memory:[8128K]
# column:[Name] check [inverse type] complete,speed:[21.56ms]/it,cpu:[34%],memory:[8276K]
# column:[Sex] check [inverse type] complete,speed:[22.42ms]/it,cpu:[53%],memory:[8992K]
# column:[Age] check [inverse type] complete,speed:[21.35ms]/it,cpu:[86%],memory:[9068K]
# column:[SibSp] check [inverse type] complete,speed:[22.62ms]/it,cpu:[41%],memory:[16928K]
# column:[Parch] check [inverse type] complete,speed:[21.89ms]/it,cpu:[60%],memory:[10980K]
# column:[Ticket] check [inverse type] complete,speed:[21.08ms]/it,cpu:[79%],memory:[20648K]
# column:[Fare] check [inverse type] complete,speed:[20.83ms]/it,cpu:[48%],memory:[15820K]
# column:[Cabin] check [inverse type] complete,speed:[21.65ms]/it,cpu:[65%],memory:[12940K]
# column:[Embarked] check [inverse type] complete,speed:[21.62ms]/it,cpu:[45%],memory:[30840K]
#
# ############################################
#  5.int数据转float测试:check_int_trans_float
# ############################################
# column:[PassengerId] check [int trans float] complete,speed:[20.31ms]/it,cpu:[24%],memory:[36K]
# column:[Pclass] check [int trans float] complete,speed:[21.88ms]/it,cpu:[17%],memory:[32K]
# column:[SibSp] check [int trans float] complete,speed:[20.51ms]/it,cpu:[25%],memory:[44K]
# column:[Parch] check [int trans float] complete,speed:[21.31ms]/it,cpu:[24%],memory:[116K]

# %% [markdown]
# ### 持久化测试

# %%
table.save("ml.pkl")

# %%
table=TablePipeLine()
table.pipe(FixInput())\
  .pipe(FillNa())\
  .pipe(Clip(cols=["Age"],default_clip=(1,99),name="clip_name"))\
  .pipe(OneHotEncoding(cols=["Pclass","Sex","Name","Ticket","Embarked","Cabin"],drop_col=True))\
  .pipe(ReduceMemUsage())\
  .pipe(Dense2Sparse())

table.load("ml.pkl")

# %%
table.auto_test(x_test[:10])
# Out:
# ###################################################################
#  1.一致性测试和性能测试:check_transform_function
# ###################################################################
# (<class 'easymlops.table.preprocessing.core.FixInput'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.FillNa'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (clip_name) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.OneHotEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.perfopt.ReduceMemUsage'>) module check [transform] complete,speed:[10.91ms]/it,cpu:[19%],memory:[0K]
# (<class 'easymlops.table.perfopt.Dense2Sparse'>) module check [transform] complete,speed:[10.94ms]/it,cpu:[18%],memory:[0K]
#
# #########################################################################################
#  2.空值测试:check_null_value
#  null_values=[None, np.nan, "null", "NULL", "nan", "NaN", "", "none", "None", " "](默认)
# ########################################################################################
# column:[PassengerId] check [null value] complete,speed:[21.65ms]/it,cpu:[21%],memory:[312K]
# column:[Pclass] check [null value] complete,speed:[22.1ms]/it,cpu:[22%],memory:[28K]
# column:[Name] check [null value] complete,speed:[22.54ms]/it,cpu:[19%],memory:[2044K]
# column:[Sex] check [null value] complete,speed:[21.84ms]/it,cpu:[18%],memory:[1028K]
# column:[Age] check [null value] complete,speed:[22.27ms]/it,cpu:[26%],memory:[28K]
# column:[SibSp] check [null value] complete,speed:[21.7ms]/it,cpu:[21%],memory:[40K]
# column:[Parch] check [null value] complete,speed:[21.64ms]/it,cpu:[24%],memory:[760K]
# column:[Ticket] check [null value] complete,speed:[25.85ms]/it,cpu:[20%],memory:[12K]
# column:[Fare] check [null value] complete,speed:[22.67ms]/it,cpu:[18%],memory:[40K]
# column:[Cabin] check [null value] complete,speed:[23.34ms]/it,cpu:[27%],memory:[544K]
# column:[Embarked] check [null value] complete,speed:[21.17ms]/it,cpu:[17%],memory:[0K]
#
# ############################################################################################################
#  3.极端值测试:check_extreme_value
#  number_extreme_values = [np.inf, 0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  category_extreme_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1", "NaN", "None"](默认)
# ###########################################################################################################
# column:[PassengerId] check [extreme value] complete,speed:[21.64ms]/it,cpu:[61%],memory:[22872K]
# column:[Pclass] check [extreme value] complete,speed:[21.95ms]/it,cpu:[49%],memory:[16900K]
# column:[Name] check [extreme value] complete,speed:[21.98ms]/it,cpu:[23%],memory:[74068K]
# column:[Sex] check [extreme value] complete,speed:[20.97ms]/it,cpu:[19%],memory:[1064K]
# column:[Age] check [extreme value] complete,speed:[21.88ms]/it,cpu:[37%],memory:[12376K]
# column:[SibSp] check [extreme value] complete,speed:[22.81ms]/it,cpu:[33%],memory:[369768K]
# column:[Parch] check [extreme value] complete,speed:[23.29ms]/it,cpu:[22%],memory:[71516K]
# column:[Ticket] check [extreme value] complete,speed:[21.73ms]/it,cpu:[21%],memory:[3764K]
# column:[Fare] check [extreme value] complete,speed:[21.24ms]/it,cpu:[59%],memory:[23152K]
# column:[Cabin] check [extreme value] complete,speed:[22.02ms]/it,cpu:[24%],memory:[7252K]
# column:[Embarked] check [extreme value] complete,speed:[21.97ms]/it,cpu:[77%],memory:[166816K]
# column:[__all__] check [extreme value] complete,speed:[21.97ms]/it,cpu:[28%],memory:[30604K]
#
# ###############################################################################################################
#  4.数据类型反转测试:check_inverse_dtype
#  category_inverse_values = [0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  number_inverse_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1"](默认)
# #############################################################################################################
# column:[PassengerId] check [inverse type] complete,speed:[21.63ms]/it,cpu:[29%],memory:[12984K]
# column:[Pclass] check [inverse type] complete,speed:[21.67ms]/it,cpu:[33%],memory:[55944K]
# column:[Name] check [inverse type] complete,speed:[21.14ms]/it,cpu:[45%],memory:[17956K]
# column:[Sex] check [inverse type] complete,speed:[22.06ms]/it,cpu:[19%],memory:[13860K]
# column:[Age] check [inverse type] complete,speed:[22.85ms]/it,cpu:[20%],memory:[28216K]
# column:[SibSp] check [inverse type] complete,speed:[22.46ms]/it,cpu:[41%],memory:[8368K]
# column:[Parch] check [inverse type] complete,speed:[22.0ms]/it,cpu:[38%],memory:[7196K]
# column:[Ticket] check [inverse type] complete,speed:[22.55ms]/it,cpu:[41%],memory:[1464K]
# column:[Fare] check [inverse type] complete,speed:[21.6ms]/it,cpu:[60%],memory:[6364K]
# column:[Cabin] check [inverse type] complete,speed:[22.11ms]/it,cpu:[26%],memory:[15036K]
# column:[Embarked] check [inverse type] complete,speed:[22.18ms]/it,cpu:[26%],memory:[10288K]
#
# ############################################
#  5.int数据转float测试:check_int_trans_float
# ############################################
# column:[PassengerId] check [int trans float] complete,speed:[20.03ms]/it,cpu:[22%],memory:[0K]
# column:[Pclass] check [int trans float] complete,speed:[21.88ms]/it,cpu:[22%],memory:[28K]
# column:[SibSp] check [int trans float] complete,speed:[22.66ms]/it,cpu:[24%],memory:[32K]
# column:[Parch] check [int trans float] complete,speed:[23.52ms]/it,cpu:[43%],memory:[128K]

# %%
table.transform(x_test[:5])
# Out:
#      PassengerId   Age  SibSp  Parch        Fare  Pclass_3  Pclass_1  \
# 391          392  21.0      0      0    7.796875         1         0
# 392          393  28.0      2      0    7.925781         1         0
# 393          394  23.0      1      0  113.250000         0         1
# 394          395  24.0      0      2   16.703125         1         0
# 395          396  22.0      0      0    7.796875         1         0
#
#      Pclass_2  Sex_male  Sex_female  ...  Cabin_C124  Cabin_C91  Cabin_E40  \
# 391         0         1           0  ...           0          0          0
# 392         0         1           0  ...           0          0          0
# 393         0         0           1  ...           0          0          0
# 394         0         0           1  ...           0          0          0
# 395         0         1           0  ...           0          0          0
#
#      Cabin_T  Cabin_C128  Cabin_D37  Cabin_B35  Cabin_E50  Cabin_C82  \
# 391        0           0          0          0          0          0
# 392        0           0          0          0          0          0
# 393        0           0          0          0          0          0
# 394        0           0          0          0          0          0
# 395        0           0          0          0          0          0
#
#      Cabin_B96 B98
# 391              0
# 392              0
# 393              0
# 394              0
# 395              0
#
# [5 rows x 814 columns]

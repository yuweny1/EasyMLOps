# %%
import os
os.chdir("../../")#与easymlops同级目录

# %% [markdown]
# ### 拆分数据

# %%
import pandas as pd
data=pd.read_csv("./data/demo.csv")
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
x_train=data[:500]
x_test=data[500:]
y_train=x_train["Survived"]
y_test=x_test["Survived"]
del x_train["Survived"]
del x_test["Survived"]

# %% [markdown]
# ### pipeline运行到指定层
# 我们有时候可能想看看pipeline过程中特征逐层的变化情况，以及复用别人的特征工程（但又不需要最后几步的变化），transform/transform_single中的run_to_layer就可以排上用场了

# %%
from easymlops import TablePipeLine
from easymlops.table.preprocessing import *
from easymlops.table.encoding import *
from easymlops.table.perfopt import *
from easymlops.table.decomposition import *
from easymlops.table.ensemble import *

# %%
table=TablePipeLine()
table.pipe(FixInput())\
  .pipe(FillNa())\
  .pipe(Parallel([OneHotEncoding(cols=["Pclass","Sex"],drop_col=False),
                 TablePipeLine().pipe(TargetEncoding(cols=["Embarked","Cabin"],y=y_train,name="target_encoding")).pipe(FillNa()),
                 WOEEncoding(cols=["Sex","Pclass"],y=y_train),
                 TablePipeLine().pipe(LabelEncoding(cols=["Name","Ticket"])).pipe(DropCols(cols=["Name","Sex","Ticket","Cabin","Emarked"]))]))\
  .pipe(TargetEncoding(cols=["Name","Cabin","Embarked","Ticket"],y=y_train))\
  .pipe(FillNa())\
  .pipe(Normalizer())\
  .pipe(PCADecomposition(n_components=8))

x_test_new=table.fit(x_train).transform(x_test)
x_test_new.head(5)
# Out:
#             0         1         2         3         4         5         6  \
# 500 -2.310356 -0.092862 -0.193980  0.511277  0.202237 -1.864721 -0.249380
# 501  0.180246 -1.919933 -0.315418  1.021282 -1.915737 -1.621472 -1.472875
# 502  0.115275 -2.264003 -0.104098  1.126406 -1.479052 -1.513712 -2.141663
# 503 -0.020280 -1.646040 -0.728745 -0.034924 -2.074951 -2.247727  0.120190
# 504  2.474372  0.881527  0.045653 -0.240732 -1.785365 -1.932570 -1.004863
#
#             7
# 500 -0.255635
# 501  0.604476
# 502 -0.044148
# 503 -0.132674
# 504 -1.339235

# %% [markdown]
# 浅层访问,run_to_layer设置为指定层的index

# %%
#查看第1层的数据
table.transform(x_test,run_to_layer=1).head(5)
# Out:
#      PassengerId  Pclass                            Name     Sex   Age  SibSp  \
# 500          501       3                Calic, Mr. Petar    male  17.0      0
# 501          502       3             Canavan, Miss. Mary  female  21.0      0
# 502          503       3  O'Sullivan, Miss. Bridget Mary  female   0.0      0
# 503          504       3  Laitinen, Miss. Kristina Sofia  female  37.0      0
# 504          505       1           Maioni, Miss. Roberta  female  16.0      0
#
#      Parch  Ticket       Fare Cabin Embarked
# 500      0  315086   8.664062   nan        S
# 501      0  364846   7.750000   nan        Q
# 502      0  330909   7.628906   nan        Q
# 503      0    4135   9.585938   nan        S
# 504      0  110152  86.500000   B79        S

# %%
#查看第2层的数据
table.transform(x_test,run_to_layer=2).head(5)
# Out:
#      Pclass_3  Pclass_1  Pclass_2  Sex_male  Sex_female  \
# 500         1         0         0         1           0
# 501         1         0         0         0           1
# 502         1         0         0         0           1
# 503         1         0         0         0           1
# 504         0         1         0         0           1
#
#                                Name       Sex  Ticket Cabin  PassengerId  \
# 500                Calic, Mr. Petar  1.111379  315086   nan          501
# 501             Canavan, Miss. Mary -1.569990  364846   nan          502
# 502  O'Sullivan, Miss. Bridget Mary -1.569990  330909   nan          503
# 503  Laitinen, Miss. Kristina Sofia -1.569990    4135   nan          504
# 504           Maioni, Miss. Roberta -1.569990  110152   B79          505
#
#      Pclass   Age  SibSp  Parch       Fare Embarked
# 500       3  17.0      0      0   8.664062        S
# 501       3  21.0      0      0   7.750000        Q
# 502       3   0.0      0      0   7.628906        Q
# 503       3  37.0      0      0   9.585938        S
# 504       1  16.0      0      0  86.500000        S

# %%
#查看倒数第3层的数据
table.transform(x_test,run_to_layer=-3).head(5)
# Out:
#      Pclass_3  Pclass_1  Pclass_2  Sex_male  Sex_female  Name       Sex  \
# 500         1         0         0         1           0   0.0  1.111379
# 501         1         0         0         0           1   0.0 -1.569990
# 502         1         0         0         0           1   0.0 -1.569990
# 503         1         0         0         0           1   0.0 -1.569990
# 504         0         1         0         0           1   0.0 -1.569990
#
#      Ticket     Cabin  PassengerId  Pclass   Age  SibSp  Parch       Fare  \
# 500     0.0  0.317829          501       3  17.0      0      0   8.664062
# 501     0.0  0.317829          502       3  21.0      0      0   7.750000
# 502     0.0  0.317829          503       3   0.0      0      0   7.628906
# 503     0.0  0.317829          504       3  37.0      0      0   9.585938
# 504     1.0  0.000000          505       1  16.0      0      0  86.500000
#
#      Embarked
# 500  0.334254
# 501  0.511111
# 502  0.511111
# 503  0.334254
# 504  0.334254

# %% [markdown]
# 嵌套层的范围:将run_to_layer设置为list结构，分别指定逐层的index

# %%
#查看第2层(Parallel)的第0层(OneHotEncoding)
table.transform(x_test,run_to_layer=[2,0]).head(5)
# Out:
#      PassengerId  Pclass                            Name     Sex   Age  SibSp  \
# 500          501       3                Calic, Mr. Petar    male  17.0      0
# 501          502       3             Canavan, Miss. Mary  female  21.0      0
# 502          503       3  O'Sullivan, Miss. Bridget Mary  female   0.0      0
# 503          504       3  Laitinen, Miss. Kristina Sofia  female  37.0      0
# 504          505       1           Maioni, Miss. Roberta  female  16.0      0
#
#      Parch  Ticket       Fare Cabin Embarked  Pclass_3  Pclass_1  Pclass_2  \
# 500      0  315086   8.664062   nan        S         1         0         0
# 501      0  364846   7.750000   nan        Q         1         0         0
# 502      0  330909   7.628906   nan        Q         1         0         0
# 503      0    4135   9.585938   nan        S         1         0         0
# 504      0  110152  86.500000   B79        S         0         1         0
#
#      Sex_male  Sex_female
# 500         1           0
# 501         0           1
# 502         0           1
# 503         0           1
# 504         0           1

# %%
#运行到第2层(Parallel)的第1层(TablePipeLine)的第0层(TargetEncoding)
table.transform(x_test,run_to_layer=[2,1,0]).head(5)
# Out:
#      PassengerId  Pclass                            Name     Sex   Age  SibSp  \
# 500          501       3                Calic, Mr. Petar    male  17.0      0
# 501          502       3             Canavan, Miss. Mary  female  21.0      0
# 502          503       3  O'Sullivan, Miss. Bridget Mary  female   0.0      0
# 503          504       3  Laitinen, Miss. Kristina Sofia  female  37.0      0
# 504          505       1           Maioni, Miss. Roberta  female  16.0      0
#
#      Parch  Ticket       Fare     Cabin  Embarked
# 500      0  315086   8.664062  0.317829  0.334254
# 501      0  364846   7.750000  0.317829  0.511111
# 502      0  330909   7.628906  0.317829  0.511111
# 503      0    4135   9.585938  0.317829  0.334254
# 504      0  110152  86.500000  0.000000  0.334254

# %% [markdown]
# 命名访问:如果有对模块命名，可以通过指定名称的方式访问

# %%
#查看到模块名为target_encoding的数据
table.transform(x_test,run_to_layer="target_encoding").head(5)
# Out:
#      PassengerId  Pclass                            Name     Sex   Age  SibSp  \
# 500          501       3                Calic, Mr. Petar    male  17.0      0
# 501          502       3             Canavan, Miss. Mary  female  21.0      0
# 502          503       3  O'Sullivan, Miss. Bridget Mary  female   0.0      0
# 503          504       3  Laitinen, Miss. Kristina Sofia  female  37.0      0
# 504          505       1           Maioni, Miss. Roberta  female  16.0      0
#
#      Parch  Ticket       Fare     Cabin  Embarked
# 500      0  315086   8.664062  0.317829  0.334254
# 501      0  364846   7.750000  0.317829  0.511111
# 502      0  330909   7.628906  0.317829  0.511111
# 503      0    4135   9.585938  0.317829  0.334254
# 504      0  110152  86.500000  0.000000  0.334254

# %% [markdown]
# ### 性能、一致性测试

# %%
table.auto_test(x_test[:10])
# Out:
# ###################################################################
#  1.一致性测试和性能测试:check_transform_function
# ###################################################################
# (<class 'easymlops.table.preprocessing.core.FixInput'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.FillNa'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.ensemble.Parallel'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.TargetEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.FillNa'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.Normalizer'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.decomposition.PCADecomposition'>) module check [transform] complete,speed:[3.12ms]/it,cpu:[50%],memory:[0K]
#
# #########################################################################################
#  2.空值测试:check_null_value
#  null_values=[None, np.nan, "null", "NULL", "nan", "NaN", "", "none", "None", " "](默认)
# ########################################################################################
# column:[PassengerId] check [null value] complete,speed:[4.52ms]/it,cpu:[97%],memory:[0K]
# column:[Pclass] check [null value] complete,speed:[4.61ms]/it,cpu:[78%],memory:[20K]
# column:[Name] check [null value] complete,speed:[4.51ms]/it,cpu:[88%],memory:[0K]
# column:[Sex] check [null value] complete,speed:[4.21ms]/it,cpu:[48%],memory:[4K]
# column:[Age] check [null value] complete,speed:[3.99ms]/it,cpu:[47%],memory:[12K]
# column:[SibSp] check [null value] complete,speed:[4.26ms]/it,cpu:[59%],memory:[68K]
# column:[Parch] check [null value] complete,speed:[4.26ms]/it,cpu:[51%],memory:[0K]
# column:[Ticket] check [null value] complete,speed:[3.98ms]/it,cpu:[50%],memory:[0K]
# column:[Fare] check [null value] complete,speed:[3.98ms]/it,cpu:[52%],memory:[0K]
# column:[Cabin] check [null value] complete,speed:[4.12ms]/it,cpu:[53%],memory:[0K]
# column:[Embarked] check [null value] complete,speed:[4.02ms]/it,cpu:[65%],memory:[0K]
#
# ############################################################################################################
#  3.极端值测试:check_extreme_value
#  number_extreme_values = [np.inf, 0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  category_extreme_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1", "NaN", "None"](默认)
# ###########################################################################################################
# column:[PassengerId] check [extreme value] complete,speed:[4.65ms]/it,cpu:[95%],memory:[27152K]
# column:[Pclass] check [extreme value] complete,speed:[4.94ms]/it,cpu:[92%],memory:[89180K]
# column:[Name] check [extreme value] complete,speed:[4.66ms]/it,cpu:[100%],memory:[18112K]
# column:[Sex] check [extreme value] complete,speed:[4.46ms]/it,cpu:[91%],memory:[1276K]
# column:[Age] check [extreme value] complete,speed:[4.0ms]/it,cpu:[81%],memory:[17144K]
# column:[SibSp] check [extreme value] complete,speed:[4.54ms]/it,cpu:[85%],memory:[64572K]
# column:[Parch] check [extreme value] complete,speed:[4.16ms]/it,cpu:[74%],memory:[18524K]
# column:[Ticket] check [extreme value] complete,speed:[4.21ms]/it,cpu:[97%],memory:[508K]
# column:[Fare] check [extreme value] complete,speed:[4.31ms]/it,cpu:[91%],memory:[168K]
# column:[Cabin] check [extreme value] complete,speed:[4.67ms]/it,cpu:[98%],memory:[388K]
# column:[Embarked] check [extreme value] complete,speed:[3.83ms]/it,cpu:[81%],memory:[144K]
# column:[__all__] check [extreme value] complete,speed:[4.35ms]/it,cpu:[100%],memory:[548K]
#
# ###############################################################################################################
#  4.数据类型反转测试:check_inverse_dtype
#  category_inverse_values = [0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  number_inverse_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1"](默认)
# #############################################################################################################
# column:[PassengerId] check [inverse type] complete,speed:[4.06ms]/it,cpu:[60%],memory:[400K]
# column:[Pclass] check [inverse type] complete,speed:[4.63ms]/it,cpu:[92%],memory:[132K]
# column:[Name] check [inverse type] complete,speed:[4.34ms]/it,cpu:[71%],memory:[576K]
# column:[Sex] check [inverse type] complete,speed:[4.32ms]/it,cpu:[91%],memory:[664K]
# column:[Age] check [inverse type] complete,speed:[4.71ms]/it,cpu:[87%],memory:[35448K]
# column:[SibSp] check [inverse type] complete,speed:[4.6ms]/it,cpu:[100%],memory:[8344K]
# column:[Parch] check [inverse type] complete,speed:[4.67ms]/it,cpu:[97%],memory:[892K]
# column:[Ticket] check [inverse type] complete,speed:[4.03ms]/it,cpu:[61%],memory:[684K]
# column:[Fare] check [inverse type] complete,speed:[5.37ms]/it,cpu:[98%],memory:[14268K]
# column:[Cabin] check [inverse type] complete,speed:[5.12ms]/it,cpu:[92%],memory:[94500K]
# column:[Embarked] check [inverse type] complete,speed:[4.17ms]/it,cpu:[94%],memory:[13880K]
#
# ############################################
#  5.int数据转float测试:check_int_trans_float
# ############################################
# column:[PassengerId] check [int trans float] complete,speed:[3.45ms]/it,cpu:[74%],memory:[0K]
# column:[Pclass] check [int trans float] complete,speed:[3.84ms]/it,cpu:[68%],memory:[16K]
# column:[SibSp] check [int trans float] complete,speed:[4.69ms]/it,cpu:[54%],memory:[4K]
# column:[Parch] check [int trans float] complete,speed:[3.12ms]/it,cpu:[58%],memory:[4K]

# %% [markdown]
# ### 持久化测试

# %%
table.save("ml.pkl")

# %%
table=TablePipeLine()
table.pipe(FixInput())\
  .pipe(FillNa())\
  .pipe(Parallel([OneHotEncoding(cols=["Pclass","Sex"],drop_col=False),
                 TablePipeLine().pipe(TargetEncoding(cols=["Embarked","Cabin"],y=y_train,name="target_encoding")).pipe(FillNa()),
                 WOEEncoding(cols=["Sex","Pclass"]),
                 TablePipeLine().pipe(LabelEncoding(cols=["Name","Ticket"])).pipe(DropCols(cols=["Name","Sex","Ticket","Cabin","Emarked"]))]))\
  .pipe(TargetEncoding(cols=["Name","Cabin","Embarked","Ticket"]))\
  .pipe(FillNa())\
  .pipe(Normalizer())\
  .pipe(PCADecomposition(n_components=8))


table.load("ml.pkl")

# %%
table.auto_test(x_test[:10])
# Out:
# ###################################################################
#  1.一致性测试和性能测试:check_transform_function
# ###################################################################
# (<class 'easymlops.table.preprocessing.core.FixInput'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.FillNa'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.ensemble.Parallel'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.TargetEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.FillNa'>) module check [transform] complete,speed:[1.56ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.Normalizer'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.decomposition.PCADecomposition'>) module check [transform] complete,speed:[3.13ms]/it,cpu:[50%],memory:[0K]
#
# #########################################################################################
#  2.空值测试:check_null_value
#  null_values=[None, np.nan, "null", "NULL", "nan", "NaN", "", "none", "None", " "](默认)
# ########################################################################################
# column:[PassengerId] check [null value] complete,speed:[4.04ms]/it,cpu:[66%],memory:[0K]
# column:[Pclass] check [null value] complete,speed:[4.75ms]/it,cpu:[88%],memory:[0K]
# column:[Name] check [null value] complete,speed:[3.88ms]/it,cpu:[51%],memory:[0K]
# column:[Sex] check [null value] complete,speed:[4.07ms]/it,cpu:[52%],memory:[20K]
# column:[Age] check [null value] complete,speed:[4.62ms]/it,cpu:[77%],memory:[4K]
# column:[SibSp] check [null value] complete,speed:[4.62ms]/it,cpu:[66%],memory:[2292K]
# column:[Parch] check [null value] complete,speed:[4.44ms]/it,cpu:[52%],memory:[0K]
# column:[Ticket] check [null value] complete,speed:[4.38ms]/it,cpu:[57%],memory:[8K]
# column:[Fare] check [null value] complete,speed:[3.98ms]/it,cpu:[72%],memory:[0K]
# column:[Cabin] check [null value] complete,speed:[4.11ms]/it,cpu:[36%],memory:[0K]
# column:[Embarked] check [null value] complete,speed:[3.95ms]/it,cpu:[33%],memory:[0K]
#
# ############################################################################################################
#  3.极端值测试:check_extreme_value
#  number_extreme_values = [np.inf, 0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  category_extreme_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1", "NaN", "None"](默认)
# ###########################################################################################################
# column:[PassengerId] check [extreme value] complete,speed:[3.67ms]/it,cpu:[85%],memory:[6776380K]
# column:[Pclass] check [extreme value] complete,speed:[4.04ms]/it,cpu:[70%],memory:[472K]
# column:[Name] check [extreme value] complete,speed:[3.91ms]/it,cpu:[44%],memory:[216K]
# column:[Sex] check [extreme value] complete,speed:[3.84ms]/it,cpu:[54%],memory:[104K]
# column:[Age] check [extreme value] complete,speed:[4.04ms]/it,cpu:[76%],memory:[6779404K]
# column:[SibSp] check [extreme value] complete,speed:[4.21ms]/it,cpu:[65%],memory:[6779520K]
# column:[Parch] check [extreme value] complete,speed:[3.78ms]/it,cpu:[73%],memory:[1852K]
# column:[Ticket] check [extreme value] complete,speed:[5.2ms]/it,cpu:[77%],memory:[1328K]
# column:[Fare] check [extreme value] complete,speed:[4.54ms]/it,cpu:[83%],memory:[111416K]
# column:[Cabin] check [extreme value] complete,speed:[4.29ms]/it,cpu:[87%],memory:[6717308K]
# column:[Embarked] check [extreme value] complete,speed:[5.45ms]/it,cpu:[93%],memory:[176K]
# column:[__all__] check [extreme value] complete,speed:[3.97ms]/it,cpu:[71%],memory:[212K]
#
# ###############################################################################################################
#  4.数据类型反转测试:check_inverse_dtype
#  category_inverse_values = [0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  number_inverse_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1"](默认)
# #############################################################################################################
# column:[PassengerId] check [inverse type] complete,speed:[4.06ms]/it,cpu:[53%],memory:[32K]
# column:[Pclass] check [inverse type] complete,speed:[3.96ms]/it,cpu:[72%],memory:[1588K]
# column:[Name] check [inverse type] complete,speed:[5.14ms]/it,cpu:[78%],memory:[4356K]
# column:[Sex] check [inverse type] complete,speed:[3.38ms]/it,cpu:[50%],memory:[6703016K]
# column:[Age] check [inverse type] complete,speed:[3.85ms]/it,cpu:[42%],memory:[6701060K]
# column:[SibSp] check [inverse type] complete,speed:[4.1ms]/it,cpu:[40%],memory:[416K]
# column:[Parch] check [inverse type] complete,speed:[3.9ms]/it,cpu:[20%],memory:[604K]
# column:[Ticket] check [inverse type] complete,speed:[3.68ms]/it,cpu:[21%],memory:[6700000K]
# column:[Fare] check [inverse type] complete,speed:[4.03ms]/it,cpu:[66%],memory:[220K]
# column:[Cabin] check [inverse type] complete,speed:[4.37ms]/it,cpu:[62%],memory:[33088K]
# column:[Embarked] check [inverse type] complete,speed:[4.75ms]/it,cpu:[42%],memory:[11804K]
#
# ############################################
#  5.int数据转float测试:check_int_trans_float
# ############################################
# column:[PassengerId] check [int trans float] complete,speed:[4.69ms]/it,cpu:[20%],memory:[0K]
# column:[Pclass] check [int trans float] complete,speed:[7.81ms]/it,cpu:[20%],memory:[28K]
# column:[SibSp] check [int trans float] complete,speed:[5.39ms]/it,cpu:[24%],memory:[0K]
# column:[Parch] check [int trans float] complete,speed:[3.65ms]/it,cpu:[53%],memory:[0K]

# %%
table.transform(x_test[:5])
# Out:
#             0         1         2         3         4         5         6  \
# 500 -2.310356 -0.092862 -0.193980  0.511277  0.202237 -1.864721 -0.249380
# 501  0.180246 -1.919933 -0.315418  1.021282 -1.915737 -1.621472 -1.472875
# 502  0.115275 -2.264003 -0.104098  1.126406 -1.479052 -1.513712 -2.141663
# 503 -0.020280 -1.646040 -0.728745 -0.034924 -2.074951 -2.247727  0.120190
# 504  2.474372  0.881527  0.045653 -0.240732 -1.785365 -1.932570 -1.004863
#
#             7
# 500 -0.255635
# 501  0.604476
# 502 -0.044148
# 503 -0.132674
# 504 -1.339235

# %%
x_test_new.head(5)
# Out:
#             0         1         2         3         4         5         6  \
# 500 -2.310356 -0.092862 -0.193980  0.511277  0.202237 -1.864721 -0.249380
# 501  0.180246 -1.919933 -0.315418  1.021282 -1.915737 -1.621472 -1.472875
# 502  0.115275 -2.264003 -0.104098  1.126406 -1.479052 -1.513712 -2.141663
# 503 -0.020280 -1.646040 -0.728745 -0.034924 -2.074951 -2.247727  0.120190
# 504  2.474372  0.881527  0.045653 -0.240732 -1.785365 -1.932570 -1.004863
#
#             7
# 500 -0.255635
# 501  0.604476
# 502 -0.044148
# 503 -0.132674
# 504 -1.339235

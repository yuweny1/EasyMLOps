# %%
import os
os.chdir("../../")#与easymlops同级目录

# %% [markdown]
# ### 拆分数据

# %%
import pandas as pd
data=pd.read_csv("./data/demo.csv")
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
x_train=data[:500]
x_test=data[500:]
y_train=x_train["Survived"]
y_test=x_test["Survived"]
del x_train["Survived"]
del x_test["Survived"]

# %% [markdown]
# ### pipe构建

# %%
from easymlops import TablePipeLine
from easymlops.table.preprocessing import *
from easymlops.table.encoding import *
from easymlops.table.feature_selection import *
from easymlops.table.ensemble import Parallel

# %%
table=TablePipeLine()
table.pipe(FixInput())\
  .pipe(FillNa())\
  .pipe(MissRateFilter(max_threshold=0.1))\
  .pipe(VarianceFilter(min_threshold=0.1))\
  .pipe(PersonCorrFilter(min_threshold=0.1,y=y_train,name="person"))\
  .pipe(PSIFilter(oot_x=x_test,cols=["Pclass","Sex","Embarked"],name="psi",max_threshold=0.5))\
  .pipe(LabelEncoding(cols=["Sex","Ticket","Embarked","Pclass"]))\
  .pipe(TargetEncoding(cols=["Name"],y=y_train))\
  .pipe(Chi2Filter(y=y_train,name="chi2"))\
  .pipe(MutualInfoFilter(y=y_train))\
  .pipe(IVFilter(y=y_train,name="iv",cols=["Sex","Fare"],min_threshold=0.05))

x_test_new=table.fit(x_train).transform(x_test)
x_test_new.head(5)
# Out:
#      Pclass  Name  Sex  Ticket       Fare  Embarked
# 500       1   0.0    1       0   8.664062         1
# 501       1   0.0    2       0   7.750000         3
# 502       1   0.0    2       0   7.628906         3
# 503       1   0.0    2       0   9.585938         1
# 504       2   0.0    2     231  86.500000         1

# %%
#查看psi计算详情
table["psi"].show_detail().head()
# Out:
#       col bin_value  ins_num  ins_rate  oot_num  oot_rate       psi
# 0  Pclass         3      279     0.558      212  0.542199  0.000454
# 1  Pclass         1      116     0.232      100  0.255754  0.002316
# 2  Pclass         2      105     0.210       79  0.202046  0.000307
# 3     Sex      male      315     0.630      262  0.670077  0.002472
# 4     Sex    female      185     0.370      129  0.329923  0.004595

# %% [markdown]
# ### 性能、一致性测试

# %%
table.auto_test(x_test[:10])
# Out:
# ###################################################################
#  1.一致性测试和性能测试:check_transform_function
# ###################################################################
# (<class 'easymlops.table.preprocessing.core.FixInput'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.FillNa'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.feature_selection.filter.MissRateFilter'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.feature_selection.filter.VarianceFilter'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (person) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (psi) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.LabelEncoding'>) module check [transform] complete,speed:[0.1ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.TargetEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (chi2) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.feature_selection.filter.MutualInfoFilter'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (iv) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
#
# #########################################################################################
#  2.空值测试:check_null_value
#  null_values=[None, np.nan, "null", "NULL", "nan", "NaN", "", "none", "None", " "](默认)
# ########################################################################################
# column:[PassengerId] check [null value] complete,speed:[0.4ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [null value] complete,speed:[0.48ms]/it,cpu:[0%],memory:[0K]
# column:[Name] check [null value] complete,speed:[0.63ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [null value] complete,speed:[0.38ms]/it,cpu:[0%],memory:[0K]
# column:[Age] check [null value] complete,speed:[0.23ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [null value] complete,speed:[0.59ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [null value] complete,speed:[0.31ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [null value] complete,speed:[0.46ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [null value] complete,speed:[0.33ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [null value] complete,speed:[0.41ms]/it,cpu:[0%],memory:[0K]
# column:[Embarked] check [null value] complete,speed:[0.39ms]/it,cpu:[0%],memory:[0K]
#
# ############################################################################################################
#  3.极端值测试:check_extreme_value
#  number_extreme_values = [np.inf, 0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  category_extreme_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1", "NaN", "None"](默认)
# ###########################################################################################################
# column:[PassengerId] check [extreme value] complete,speed:[0.12ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [extreme value] complete,speed:[0.5ms]/it,cpu:[0%],memory:[0K]
# column:[Name] check [extreme value] complete,speed:[0.28ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [extreme value] complete,speed:[0.16ms]/it,cpu:[0%],memory:[0K]
# column:[Age] check [extreme value] complete,speed:[0.47ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [extreme value] complete,speed:[0.3ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [extreme value] complete,speed:[0.31ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [extreme value] complete,speed:[0.5ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [extreme value] complete,speed:[0.27ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [extreme value] complete,speed:[0.54ms]/it,cpu:[0%],memory:[0K]
# column:[Embarked] check [extreme value] complete,speed:[0.31ms]/it,cpu:[0%],memory:[0K]
# column:[__all__] check [extreme value] complete,speed:[0.47ms]/it,cpu:[0%],memory:[0K]
#
# ###############################################################################################################
#  4.数据类型反转测试:check_inverse_dtype
#  category_inverse_values = [0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  number_inverse_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1"](默认)
# #############################################################################################################
# column:[PassengerId] check [inverse type] complete,speed:[0.23ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [inverse type] complete,speed:[0.45ms]/it,cpu:[0%],memory:[0K]
# column:[Name] check [inverse type] complete,speed:[0.52ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [inverse type] complete,speed:[0.87ms]/it,cpu:[0%],memory:[0K]
# column:[Age] check [inverse type] complete,speed:[0.22ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [inverse type] complete,speed:[0.39ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [inverse type] complete,speed:[0.67ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [inverse type] complete,speed:[0.35ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [inverse type] complete,speed:[0.45ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [inverse type] complete,speed:[0.35ms]/it,cpu:[0%],memory:[0K]
# column:[Embarked] check [inverse type] complete,speed:[0.18ms]/it,cpu:[0%],memory:[0K]
#
# ############################################
#  5.int数据转float测试:check_int_trans_float
# ############################################
# column:[PassengerId] check [int trans float] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [int trans float] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [int trans float] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [int trans float] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]

# %% [markdown]
# ### 持久化测试

# %%
table.save("ml.pkl")

# %%
table=TablePipeLine()
table.pipe(FixInput())\
  .pipe(FillNa())\
  .pipe(MissRateFilter(max_threshold=0.1))\
  .pipe(VarianceFilter(min_threshold=0.1))\
  .pipe(PersonCorrFilter(min_threshold=0.1,name="person"))\
  .pipe(PSIFilter(oot_x=x_test,cols=["Pclass","Sex","Embarked"],name="psi",max_threshold=0.5))\
  .pipe(LabelEncoding(cols=["Sex","Ticket","Embarked","Pclass"]))\
  .pipe(TargetEncoding(cols=["Name","Cabin"]))\
  .pipe(Chi2Filter(name="chi2"))\
  .pipe(MutualInfoFilter())\
  .pipe(IVFilter(name="iv",cols=["Sex","Fare"],min_threshold=0.05))

table.load("ml.pkl")

# %%
table.auto_test(x_test[:10])
# Out:
# ###################################################################
#  1.一致性测试和性能测试:check_transform_function
# ###################################################################
# (<class 'easymlops.table.preprocessing.core.FixInput'>) module check [transform] complete,speed:[4.38ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.preprocessing.onevar_operation.FillNa'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.feature_selection.filter.MissRateFilter'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.feature_selection.filter.VarianceFilter'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (person) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (psi) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.LabelEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.encoding.TargetEncoding'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (chi2) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (<class 'easymlops.table.feature_selection.filter.MutualInfoFilter'>) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# (iv) module check [transform] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
#
# #########################################################################################
#  2.空值测试:check_null_value
#  null_values=[None, np.nan, "null", "NULL", "nan", "NaN", "", "none", "None", " "](默认)
# ########################################################################################
# column:[PassengerId] check [null value] complete,speed:[0.57ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [null value] complete,speed:[0.32ms]/it,cpu:[0%],memory:[0K]
# column:[Name] check [null value] complete,speed:[0.58ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [null value] complete,speed:[0.61ms]/it,cpu:[0%],memory:[0K]
# column:[Age] check [null value] complete,speed:[0.46ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [null value] complete,speed:[0.28ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [null value] complete,speed:[0.57ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [null value] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [null value] complete,speed:[0.57ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [null value] complete,speed:[0.28ms]/it,cpu:[0%],memory:[0K]
# column:[Embarked] check [null value] complete,speed:[0.57ms]/it,cpu:[0%],memory:[0K]
#
# ############################################################################################################
#  3.极端值测试:check_extreme_value
#  number_extreme_values = [np.inf, 0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  category_extreme_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1", "NaN", "None"](默认)
# ###########################################################################################################
# column:[PassengerId] check [extreme value] complete,speed:[0.7ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [extreme value] complete,speed:[0.32ms]/it,cpu:[0%],memory:[0K]
# column:[Name] check [extreme value] complete,speed:[0.62ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [extreme value] complete,speed:[0.35ms]/it,cpu:[0%],memory:[0K]
# column:[Age] check [extreme value] complete,speed:[0.16ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [extreme value] complete,speed:[0.7ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [extreme value] complete,speed:[0.48ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [extreme value] complete,speed:[0.04ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [extreme value] complete,speed:[0.62ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [extreme value] complete,speed:[0.63ms]/it,cpu:[0%],memory:[0K]
# column:[Embarked] check [extreme value] complete,speed:[0.31ms]/it,cpu:[91%],memory:[7839420K]
# column:[__all__] check [extreme value] complete,speed:[0.57ms]/it,cpu:[0%],memory:[0K]
#
# ###############################################################################################################
#  4.数据类型反转测试:check_inverse_dtype
#  category_inverse_values = [0.0, -1, 1, -1e-7, 1e-7, np.finfo(np.float64).min, np.finfo(np.float64).max](默认)
#  number_inverse_values = ["", "null", None, "1.0", "0.0", "-1.0", "-1"](默认)
# #############################################################################################################
# column:[PassengerId] check [inverse type] complete,speed:[0.28ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [inverse type] complete,speed:[0.22ms]/it,cpu:[0%],memory:[0K]
# column:[Name] check [inverse type] complete,speed:[0.52ms]/it,cpu:[0%],memory:[0K]
# column:[Sex] check [inverse type] complete,speed:[0.39ms]/it,cpu:[0%],memory:[0K]
# column:[Age] check [inverse type] complete,speed:[0.45ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [inverse type] complete,speed:[0.35ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [inverse type] complete,speed:[0.22ms]/it,cpu:[0%],memory:[0K]
# column:[Ticket] check [inverse type] complete,speed:[0.35ms]/it,cpu:[0%],memory:[0K]
# column:[Fare] check [inverse type] complete,speed:[0.22ms]/it,cpu:[0%],memory:[0K]
# column:[Cabin] check [inverse type] complete,speed:[0.41ms]/it,cpu:[0%],memory:[0K]
# column:[Embarked] check [inverse type] complete,speed:[0.55ms]/it,cpu:[0%],memory:[0K]
#
# ############################################
#  5.int数据转float测试:check_int_trans_float
# ############################################
# column:[PassengerId] check [int trans float] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# column:[Pclass] check [int trans float] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]
# column:[SibSp] check [int trans float] complete,speed:[1.58ms]/it,cpu:[0%],memory:[0K]
# column:[Parch] check [int trans float] complete,speed:[0.0ms]/it,cpu:[0%],memory:[0K]

# %%
table.transform(x_test[:5])
# Out:
#      Pclass  Name  Sex  Ticket       Fare  Embarked
# 500       1   0.0    1       0   8.664062         1
# 501       1   0.0    2       0   7.750000         3
# 502       1   0.0    2       0   7.628906         3
# 503       1   0.0    2       0   9.585938         1
# 504       2   0.0    2     231  86.500000         1

# %%
x_test_new.head(5)
# Out:
#      Pclass  Name  Sex  Ticket       Fare  Embarked
# 500       1   0.0    1       0   8.664062         1
# 501       1   0.0    2       0   7.750000         3
# 502       1   0.0    2       0   7.628906         3
# 503       1   0.0    2       0   9.585938         1
# 504       2   0.0    2     231  86.500000         1
